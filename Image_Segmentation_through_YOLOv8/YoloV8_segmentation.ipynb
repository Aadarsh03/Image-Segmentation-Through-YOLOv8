# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 333.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 298.2 kB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO 
from IPython.display import Image
yolo8_model_segmentation = YOLO('yolov8n-seg.pt')

# %%
yolo8_model_segmentation.predict(source="input_images/dog-park-petting-dog.jpeg",save_txt=True,save=True,exist_ok=True)
Image(filename="runs/segment/predict/dog-park-petting-dog.jpeg", height=300,width=500)
# Out:
# image 1/1 /Users/kamal/IVP_YOLOv8/input_images/dog-park-petting-dog.jpeg: 448x640 2 persons, 1 dog, 234.5ms
# Speed: 11.7ms preprocess, 234.5ms inference, 6.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 4 labels saved to runs/segment/predict/labels
